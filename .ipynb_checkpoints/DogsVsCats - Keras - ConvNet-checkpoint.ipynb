# %% [markdown]
# # A Keras Implementation of DogsVsCats

# %%
# %matplotlib inline
from __future__ import print_function


import numpy as np
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K
from loader import load_dataset
import matplotlib.pyplot as plt

# %%
# Data Paths

#full = 'data/dogsvcats.hdf5'
#X_train_orig, Y_train_orig, X_val_orig, Y_val_orig, X_test_orig, Y_test_orig = load_dataset(full)

sample = 'data/dogsvcats-sample.hdf5'
X_train_orig, Y_train_orig, X_val_orig, Y_val_orig, X_test_orig, Y_test_orig = load_dataset(sample)

# %%
index = 7
plt.imshow(X_train_orig[index])
print("y = "+str(np.squeeze(Y_train_orig[:, index])))
# Out:
# y = 0

# %%
plt.imshow(X_val_orig[index])
print("y = "+str(np.squeeze(Y_val_orig[:,index])))
# Out:
# y = 1

# %%
batch_size = 4
num_classes = 2
epochs = 12
img_rows, img_cols = 224, 224

# %%
if K.image_data_format() == 'channels_first':
    x_train = X_train_orig.reshape(X_train_orig.shape[0], 3, img_rows, img_cols)
    x_val = X_val_orig.reshape(X_val_orig.shape[0], 3, img_rows, img_cols)
    x_test = X_test_orig.reshape(X_test_orig.shape[0], 3, img_rows, img_cols)
    input_shape = (3, img_rows, img_cols)
else:
    x_train = X_train_orig.reshape(X_train_orig.shape[0], img_rows, img_cols, 3)
    x_val = X_val_orig.reshape(X_val_orig.shape[0], img_rows, img_cols, 3)
    x_test = X_test_orig.reshape(X_test_orig.shape[0], img_rows, img_cols, 3)
    input_shape = (img_rows, img_cols, 3)

# %%
x_train = x_train.astype('float32')
x_val = x_val.astype('float32')
x_test = x_test.astype('float32')
x_train /= 255
x_val /= 255
x_test /= 255
print('x_train shape:', x_train.shape)

print(x_train.shape[0], 'train samples')
print(x_val.shape[0], 'validation samples')
print(x_test.shape[0], 'test samples')
# Out:
# x_train shape: (60, 224, 224, 3)
# 60 train samples
# 20 validation samples
# 20 test samples

# %%
y_train = keras.utils.to_categorical(np.squeeze(Y_train_orig), num_classes)
y_val = keras.utils.to_categorical(np.squeeze(Y_val_orig), num_classes)
y_test = keras.utils.to_categorical(np.squeeze(Y_test_orig), num_classes)

# %%
model = Sequential()
model.add(Conv2D(32, kernel_size=(3,3), activation='relu', input_shape=input_shape))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss=keras.losses.categorical_crossentropy, optimizer=keras.optimizers.Adadelta(), metrics=['accuracy'])

model.fit(x_train, y_train, batch_size=batch_size, epochs=epochs, verbose=1, validation_data=(x_val, y_val))

score = model.evaluate(x_test, y_test, verbose=0)
print('Test loss: ', score[0])
print('Test accuracy: ', score[1])
# Out:
# Train on 60 samples, validate on 20 samples
# Epoch 1/12
# 60/60 [==============================] - 33s 551ms/step - loss: 6.0665 - acc: 0.5833 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 2/12
# 60/60 [==============================] - 32s 540ms/step - loss: 6.9090 - acc: 0.5667 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 3/12
# 60/60 [==============================] - 34s 565ms/step - loss: 7.4539 - acc: 0.5333 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 4/12
# 60/60 [==============================] - 34s 559ms/step - loss: 7.2531 - acc: 0.5500 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 5/12
# 60/60 [==============================] - 31s 523ms/step - loss: 7.2532 - acc: 0.5500 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 6/12
# 60/60 [==============================] - 31s 520ms/step - loss: 7.2531 - acc: 0.5500 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 7/12
# 60/60 [==============================] - 32s 540ms/step - loss: 7.2531 - acc: 0.5500 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 8/12
# 60/60 [==============================] - 32s 535ms/step - loss: 7.2531 - acc: 0.5500 - val_loss: 8.0590 - val_acc: 0.5000
# Epoch 9/12
# 60/60 [==============================] - 31s 524ms/step - loss: 6.5927 - acc: 0.5833 - val_loss: 8.0459 - val_acc: 0.5000
# Epoch 10/12
# 60/60 [==============================] - 32s 533ms/step - loss: 4.4253 - acc: 0.4167 - val_loss: 0.6514 - val_acc: 0.5500
# Epoch 11/12
# 60/60 [==============================] - 32s 535ms/step - loss: 0.7340 - acc: 0.7833 - val_loss: 0.6151 - val_acc: 0.6000
# Epoch 12/12
# 60/60 [==============================] - 31s 519ms/step - loss: 1.2212 - acc: 0.7833 - val_loss: 0.5968 - val_acc: 0.6000
# Test loss:  0.787121117115
# Test accuracy:  0.40000000596
